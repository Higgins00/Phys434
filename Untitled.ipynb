# %%
import h5py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
hf = h5py.File('higgs_100000_pt_250_500.h5','r')
hf1 = h5py.File('qcd_100000_pt_250_500.h5','r')

# %%
higgs_data = np.array(hf.get('higgs_100000_pt_250_500'))
qcd_data = np.array(hf1.get('qcd_100000_pt_250_500'))

# %%
higgs_table = pd.DataFrame(higgs_data)
qcd_table = pd.DataFrame(qcd_data)

# %%
higgs_table.columns = [ 'pt', 'eta', 'phi', 'mass', 'ee2', 'ee3', 'd2', 'angularity', 't1', 't2', 't3', 't21', 't32', 'KtDeltaR']

# %%
qcd_table.columns = [ 'pt', 'eta', 'phi', 'mass', 'ee2', 'ee3', 'd2', 'angularity', 't1', 't2', 't3', 't21', 't32', 'KtDeltaR']

# %%
higgs_table
# Out:
#                pt       eta       phi        mass       ee2       ee3  \
# 0      472.074292  0.137052 -2.535145  125.150365  0.126581  0.002633
# 1      470.405678 -0.039157  0.069669  130.552672  0.118071  0.002379
# 2      438.008357 -0.181139 -3.031083  125.703063  0.167344  0.004623
# 3      484.860421  0.251986  2.855706  126.215853  0.119238  0.002066
# 4      486.141137 -1.917812 -2.221953  132.182504  0.103632  0.001438
# ...           ...       ...       ...         ...       ...       ...
# 99995  478.658254 -0.837586 -2.609921  125.707302  0.138041  0.001494
# 99996  465.171259  0.429341 -1.446681  129.749906  0.135890  0.002071
# 99997  466.920808 -0.805493 -0.754703   49.069161  0.020281  0.000121
# 99998  471.611853  0.801813 -3.077883  117.186361  0.102276  0.002399
# 99999  467.029906 -0.432315  2.483939   64.187269  0.031847  0.000260
#
#               d2  angularity        t1        t2        t3       t21  \
# ...

# %%
qcd_table
# Out:
#                pt       eta       phi        mass       ee2       ee3  \
# 0      489.631389  1.955969  1.803007  125.298720  0.099409  0.003247
# 1      401.041884 -1.170413  0.188817   88.047054  0.101181  0.002527
# 2      447.487556  1.861736 -2.326646   85.794174  0.069372  0.001375
# 3      402.652836  1.276421 -1.124176   42.947328  0.032095  0.000266
# 4      484.257672 -1.272225  1.966794   59.542227  0.038348  0.000358
# ...           ...       ...       ...         ...       ...       ...
# 99995  418.171225  1.804938 -1.555512   67.399102  0.047555  0.000669
# 99996  492.119236 -0.037258  0.037888   90.775772  0.095329  0.001090
# 99997  492.932552 -0.912632  0.578690  106.611253  0.078793  0.002331
# 99998  402.673975 -1.736921 -2.103913   66.278542  0.066585  0.000851
# 99999  454.801644  1.059727  1.462793   62.786390  0.062568  0.000652
#
#              d2  angularity        t1        t2        t3       t21       t32  \
# ...

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax[0].set_title('Transverse Momentum')
ax[0].hist(qcd_table['pt'],density = True,alpha=.6, label = 'QCD')
ax[0].hist(higgs_table['pt'],density = True,alpha=.6, label = 'Higgs')
ax[0].legend()

ax[1].set_title('Log Transverse Momentum')
ax[1].hist(qcd_table['pt'],density = True,alpha=.6, label = 'QCD')
ax[1].hist(higgs_table['pt'],density = True,alpha=.6, label = 'Higgs')
ax[1].set_yscale('log')
ax[1].legend()
plt.savefig('pt')

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax[0].set_title('Pseudorapidity')
ax[0].hist(qcd_table['eta'],density = True,alpha=.6, label = 'QCD')
ax[0].hist(higgs_table['eta'],density = True,alpha=.6, label = 'Higgs')
ax[0].legend()

ax[1].set_title('Log Pseudorapidity')
ax[1].hist(qcd_table['eta'],density = True,alpha=.6, label = 'QCD')
ax[1].hist(higgs_table['eta'],density = True,alpha=.6, label = 'Higgs')
ax[1].set_yscale('log')
ax[1].legend();
plt.savefig('eta')

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax[0].set_title('Azimuthal Angle')
ax[0].hist(qcd_table['phi'],density = True,alpha=.6, label = 'QCD')
ax[0].hist(higgs_table['phi'],density = True,alpha=.6, label = 'Higgs')
ax[0].legend()

ax[1].set_title('Log Azimuthal Angle')
ax[1].hist(qcd_table['phi'],density = True,alpha=.6, label = 'QCD')
ax[1].hist(higgs_table['phi'],density = True,alpha=.6, label = 'Higgs')
ax[1].set_yscale('log')
ax[1].legend();
plt.savefig('phi')

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax[0].set_title('Mass')
ax[0].hist(qcd_table['mass'],density = True,alpha=.6, label = 'QCD')
ax[0].hist(higgs_table['mass'],density = True,alpha=.6, label = 'Higgs')
ax[0].legend()

ax[1].set_title('Log Mass')
ax[1].hist(qcd_table['mass'],density = True,alpha=.6, label = 'QCD')
ax[1].hist(higgs_table['mass'],density = True,alpha=.6, label = 'Higgs')
ax[1].set_yscale('log')
ax[1].legend();
plt.savefig('mass')

# %%
fig,ax = plt.subplots(4,2,figsize=(10,20))
ax[0][0].set_title('ee2')
ax[0][0].hist(qcd_table['ee2'],density = True,alpha=.6, label = 'QCD')
ax[0][0].hist(higgs_table['ee2'],density = True,alpha=.6, label = 'Higgs')
ax[0][0].legend()

ax[0][1].set_title('Log ee2')
ax[0][1].hist(qcd_table['ee2'],density = True,alpha=.6, label = 'QCD')
ax[0][1].hist(higgs_table['ee2'],density = True,alpha=.6, label = 'Higgs')
ax[0][1].set_yscale('log')
ax[0][1].legend()


ax[1][0].set_title('ee3')
ax[1][0].hist(qcd_table['ee3'],density = True,alpha=.6, label = 'QCD')
ax[1][0].hist(higgs_table['ee3'],density = True,alpha=.6, label = 'Higgs')
ax[1][0].legend()

ax[1][1].set_title('Log ee3')
ax[1][1].hist(qcd_table['ee3'],density = True,alpha=.6, label = 'QCD')
ax[1][1].hist(higgs_table['ee3'],density = True,alpha=.6, label = 'Higgs')
ax[1][1].set_yscale('log')
ax[1][1].legend();


ax[2][0].set_title('d2')
ax[2][0].hist(qcd_table['d2'],density = True,alpha=.6, label = 'QCD')
ax[2][0].hist(higgs_table['d2'],density = True,alpha=.6, label = 'Higgs')
ax[2][0].legend()

ax[2][1].set_title('Log d2')
ax[2][1].hist(qcd_table['d2'],density = True,alpha=.6, label = 'QCD')
ax[2][1].hist(higgs_table['d2'],density = True,alpha=.6, label = 'Higgs')
ax[2][1].set_yscale('log')
ax[2][1].legend();


ax[3][0].set_title('angularity')
ax[3][0].hist(qcd_table['angularity'],density = True,alpha=.6, label = 'QCD')
ax[3][0].hist(higgs_table['angularity'],density = True,alpha=.6, label = 'Higgs')
ax[3][0].legend()

ax[3][1].set_title('Log angularity')
ax[3][1].hist(qcd_table['angularity'],density = True,alpha=.6, label = 'QCD')
ax[3][1].hist(higgs_table['angularity'],density = True,alpha=.6, label = 'Higgs')
ax[3][1].set_yscale('log')
ax[3][1].legend();


plt.savefig('eestuff')

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax[0].hist(qcd_table['ee3'],density = True,alpha=.6, label = 'QCD')
ax[0].hist(higgs_table['ee3'],density = True,alpha=.6, label = 'Higgs')
ax[0].legend()

ax[1].hist(qcd_table['ee3'],density = True,alpha=.6, label = 'QCD')
ax[1].hist(higgs_table['ee3'],density = True,alpha=.6, label = 'Higgs')
ax[1].set_yscale('log')
ax[1].legend();

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax[0].hist(qcd_table['d2'],density = True,alpha=.6, label = 'QCD')
ax[0].hist(higgs_table['d2'],density = True,alpha=.6, label = 'Higgs')
ax[0].legend()

ax[1].hist(qcd_table['d2'],density = True,alpha=.6, label = 'QCD')
ax[1].hist(higgs_table['d2'],density = True,alpha=.6, label = 'Higgs')
ax[1].set_yscale('log')
ax[1].legend();

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax[0].hist(qcd_table['angularity'],density = True,alpha=.6, label = 'QCD')
ax[0].hist(higgs_table['angularity'],density = True,alpha=.6, label = 'Higgs')
ax[0].legend()

ax[1].hist(qcd_table['angularity'],density = True,alpha=.6, label = 'QCD')
ax[1].hist(higgs_table['angularity'],density = True,alpha=.6, label = 'Higgs')
ax[1].set_yscale('log')
ax[1].legend();

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax[0].hist(qcd_table['t1'],density = True,alpha=.6, label = 'QCD')
ax[0].hist(higgs_table['t1'],density = True,alpha=.6, label = 'Higgs')
ax[0].legend()

ax[1].hist(qcd_table['t1'],density = True,alpha=.6, label = 'QCD')
ax[1].hist(higgs_table['t1'],density = True,alpha=.6, label = 'Higgs')
ax[1].set_yscale('log')
ax[1].legend();

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax[0].hist(qcd_table['t2'],density = True,alpha=.6, label = 'QCD')
ax[0].hist(higgs_table['t2'],density = True,alpha=.6, label = 'Higgs')
ax[0].legend()

ax[1].hist(qcd_table['t2'],density = True,alpha=.6, label = 'QCD')
ax[1].hist(higgs_table['t2'],density = True,alpha=.6, label = 'Higgs')
ax[1].set_yscale('log')
ax[1].legend();

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax[0].hist(qcd_table['t3'],density = True,alpha=.6, label = 'QCD')
ax[0].hist(higgs_table['t3'],density = True,alpha=.6, label = 'Higgs')
ax[0].legend()

ax[1].hist(qcd_table['t3'],density = True,alpha=.6, label = 'QCD')
ax[1].hist(higgs_table['t3'],density = True,alpha=.6, label = 'Higgs')
ax[1].set_yscale('log')
ax[1].legend();

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax[0].hist(qcd_table['t21'],density = True,alpha=.6, label = 'QCD')
ax[0].hist(higgs_table['t21'],density = True,alpha=.6, label = 'Higgs')
ax[0].legend()

ax[1].hist(qcd_table['t21'],density = True,alpha=.6, label = 'QCD')
ax[1].hist(higgs_table['t21'],density = True,alpha=.6, label = 'Higgs')
ax[1].set_yscale('log')
ax[1].legend();

# %%
fig,ax = plt.subplots(2,2,figsize=(10,10))
ax[0][0].set_title('t32')
ax[0][0].hist(qcd_table['t32'],density = True,alpha=.6, label = 'QCD')
ax[0][0].hist(higgs_table['t32'],density = True,alpha=.6, label = 'Higgs')
ax[0][0].legend()

ax[0][1].set_title('t32')
ax[0][1].hist(qcd_table['t32'],density = True,alpha=.6, label = 'QCD')
ax[0][1].hist(higgs_table['t32'],density = True,alpha=.6, label = 'Higgs')
ax[0][1].set_yscale('log')
ax[0][1].legend();

ax[1][0].set_title('KtDeltaR')
ax[1][0].hist(qcd_table['KtDeltaR'],density = True,alpha=.6, label = 'QCD')
ax[1][0].hist(higgs_table['KtDeltaR'],density = True,alpha=.6, label = 'Higgs')
ax[1][0].legend()

ax[1][1].set_title('KtDeltaR')
ax[1][1].hist(qcd_table['KtDeltaR'],density = True,alpha=.6, label = 'QCD')
ax[1][1].hist(higgs_table['KtDeltaR'],density = True,alpha=.6, label = 'Higgs')
ax[1][1].set_yscale('log')
ax[1][1].legend();
plt.savefig('blah')

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax[0].hist(qcd_table['KtDeltaR'],density = True,alpha=.6, label = 'QCD')
ax[0].hist(higgs_table['KtDeltaR'],density = True,alpha=.6, label = 'Higgs')
ax[0].legend()

ax[1].hist(qcd_table['KtDeltaR'],density = True,alpha=.6, label = 'QCD')
ax[1].hist(higgs_table['KtDeltaR'],density = True,alpha=.6, label = 'Higgs')
ax[1].set_yscale('log')
ax[1].legend();

# %%
plt.scatter(qcd_table['mass'],qcd_table['ee2'])
plt.scatter(higgs_table['mass'],higgs_table['ee2'])

# %%
fig,ax = plt.subplots(4,2,figsize=(10,20))
ax[0][0].set_title('t1')
ax[0][0].hist(qcd_table['t1'],density = True,alpha=.6, label = 'QCD')
ax[0][0].hist(higgs_table['t1'],density = True,alpha=.6, label = 'Higgs')
ax[0][0].legend()

ax[0][1].set_title('Log t1')
ax[0][1].hist(qcd_table['t1'],density = True,alpha=.6, label = 'QCD')
ax[0][1].hist(higgs_table['t1'],density = True,alpha=.6, label = 'Higgs')
ax[0][1].set_yscale('log')
ax[0][1].legend()


ax[1][0].set_title('t2')
ax[1][0].hist(qcd_table['t2'],density = True,alpha=.6, label = 'QCD')
ax[1][0].hist(higgs_table['t2'],density = True,alpha=.6, label = 'Higgs')
ax[1][0].legend()

ax[1][1].set_title('Log t2')
ax[1][1].hist(qcd_table['t2'],density = True,alpha=.6, label = 'QCD')
ax[1][1].hist(higgs_table['t2'],density = True,alpha=.6, label = 'Higgs')
ax[1][1].set_yscale('log')
ax[1][1].legend();


ax[2][0].set_title('t3')
ax[2][0].hist(qcd_table['t3'],density = True,alpha=.6, label = 'QCD')
ax[2][0].hist(higgs_table['t3'],density = True,alpha=.6, label = 'Higgs')
ax[2][0].legend()

ax[2][1].set_title('Log t3')
ax[2][1].hist(qcd_table['t3'],density = True,alpha=.6, label = 'QCD')
ax[2][1].hist(higgs_table['t3'],density = True,alpha=.6, label = 'Higgs')
ax[2][1].set_yscale('log')
ax[2][1].legend();


ax[3][0].set_title('t21')
ax[3][0].hist(qcd_table['t21'],density = True,alpha=.6, label = 'QCD')
ax[3][0].hist(higgs_table['t21'],density = True,alpha=.6, label = 'Higgs')
ax[3][0].legend()

ax[3][1].set_title('Log t21')
ax[3][1].hist(qcd_table['t21'],density = True,alpha=.6, label = 'QCD')
ax[3][1].hist(higgs_table['t21'],density = True,alpha=.6, label = 'Higgs')
ax[3][1].set_yscale('log')
ax[3][1].legend();


plt.savefig('ttstuff')
